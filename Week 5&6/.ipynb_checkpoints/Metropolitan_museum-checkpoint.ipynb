# %% [markdown]
# # Bellevue University
# ## DSC540-T302 Data Preparation: Summer 2021
# ### Yograj Karki
# Week 5 & 6 Assignments
# #### The Metropolitan Museum of Art <br>
# Data cleaning and transformation<br>
#
# 07/10/2021

# %%
# importing dependencies
import pandas as pd
import numpy as np

# %%
# loading the csv data file
df = pd.read_csv("MetObjects.csv", low_memory=False)
df.head()
# Out:
#   Object Number  Is Highlight  Is Timeline Work  Is Public Domain  Object ID  \
# 0    1979.486.1         False             False             False          1
# 1    1980.264.5         False             False             False          2
# 2      67.265.9         False             False             False          3
# 3     67.265.10         False             False             False          4
# 4     67.265.11         False             False             False          5
#
#   Gallery Number         Department AccessionYear Object Name  \
# 0            NaN  The American Wing          1979        Coin
# 1            NaN  The American Wing          1980        Coin
# 2            NaN  The American Wing          1967        Coin
# 3            NaN  The American Wing          1967        Coin
# 4            NaN  The American Wing          1967        Coin
#
#                           Title  ... River Classification  \
# 0  One-dollar Liberty Head Coin  ...   NaN            NaN
# ...

# %%
df.columns
# Out:
# Index(['Object Number', 'Is Highlight', 'Is Timeline Work', 'Is Public Domain',
#        'Object ID', 'Gallery Number', 'Department', 'AccessionYear',
#        'Object Name', 'Title', 'Culture', 'Period', 'Dynasty', 'Reign',
#        'Portfolio', 'Constituent ID', 'Artist Role', 'Artist Prefix',
#        'Artist Display Name', 'Artist Display Bio', 'Artist Suffix',
#        'Artist Alpha Sort', 'Artist Nationality', 'Artist Begin Date',
#        'Artist End Date', 'Artist Gender', 'Artist ULAN URL',
#        'Artist Wikidata URL', 'Object Date', 'Object Begin Date',
#        'Object End Date', 'Medium', 'Dimensions', 'Credit Line',
#        'Geography Type', 'City', 'State', 'County', 'Country', 'Region',
#        'Subregion', 'Locale', 'Locus', 'Excavation', 'River', 'Classification',
#        'Rights and Reproduction', 'Link Resource', 'Object Wikidata URL',
#        'Metadata Date', 'Repository', 'Tags', 'Tags AAT URL',
#        'Tags Wikidata URL'],
#       dtype='object')

# %%
df.shape
# Out:
# (475898, 54)

# %%
df.isnull().sum()
# Out:
# Object Number                   0
# Is Highlight                    0
# Is Timeline Work                0
# Is Public Domain                0
# Object ID                       0
# Gallery Number             432059
# Department                      0
# AccessionYear                4309
# Object Name                  1518
# Title                       29307
# Culture                    268875
# Period                     385164
# Dynasty                    452658
# Reign                      464673
# Portfolio                  452558
# Constituent ID             202183
# Artist Role                204282
# Artist Prefix              202183
# Artist Display Name        202183
# Artist Display Bio         204282
# Artist Suffix              202231
# Artist Alpha Sort          202183
# Artist Nationality         202183
# Artist Begin Date          202183
# Artist End Date            202183
# Artist Gender              373956
# Artist ULAN URL            257121
# ...

# %% [markdown]
# ### Multi Indexing

# %%
df.set_index(["Department","Classification"],inplace=True)

# %%
df.sort_index(inplace=True)

# %%
df.index
# Out:
# MultiIndex([('Ancient Near Eastern Art', '(not assigned)'),
#             ('Ancient Near Eastern Art',       'Ceramics'),
#             ('Ancient Near Eastern Art',       'Ceramics'),
#             ('Ancient Near Eastern Art',       'Ceramics'),
#             ('Ancient Near Eastern Art',       'Ceramics'),
#             ('Ancient Near Eastern Art',       'Ceramics'),
#             ('Ancient Near Eastern Art',       'Ceramics'),
#             ('Ancient Near Eastern Art',       'Ceramics'),
#             ('Ancient Near Eastern Art',       'Ceramics'),
#             ('Ancient Near Eastern Art',       'Ceramics'),
#             ...
#             (           'The Libraries',              nan),
#             (           'The Libraries',              nan),
#             (           'The Libraries',              nan),
#             (           'The Libraries',              nan),
#             (           'The Libraries',              nan),
# ...

# %%
df.reset_index(inplace=True)

# %% [markdown]
# ### Pivot the Data

# %%
df.pivot_table(values="Object ID", index="Department", columns="Region") # Selected "Object ID" arbitrarily as numeric data is needed.
# Out:
# Region                                     (Haida Gwaii) Queen Charlotte Islands  \
# Department
# Ancient Near Eastern Art                                                     NaN
# Arts of Africa, Oceania, and the Americas                               310653.0
# Egyptian Art                                                                 NaN
# Islamic Art                                                                  NaN
# Medieval Art                                                                 NaN
# Modern and Contemporary Art                                                  NaN
# Musical Instruments                                                          NaN
# The American Wing                                                            NaN
# The Cloisters                                                                NaN
#
# Region                                     1st Cataract  Abiriba region  \
# Department
# ...

# %% [markdown]
# ### Time Series

# %%
from datetime import datetime

# %%
now = datetime.now()

# %%
now
# Out:
# datetime.datetime(2021, 7, 18, 16, 22, 17, 342031)

# %%
# Convert string to date
d = "2011-11-11"
datetime.strptime(d, '%Y-%m-%d')
# Out:
# datetime.datetime(2011, 11, 11, 0, 0)

# %%
# Parse function of datetime
from dateutil.parser import parse
parse('2009-10-11')
# Out:
# datetime.datetime(2009, 10, 11, 0, 0)
